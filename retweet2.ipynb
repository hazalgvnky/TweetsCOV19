# %%
#https://matplotlib.org/gallery/color/named_colors.html
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
import math 
import seaborn as seabornInstance
import statsmodels.api as sm

from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

from scipy import stats
from scipy.stats import kurtosis, skew

# %matplotlib inline

# %%
col_data = {
    'Tweet ID' : str, 
    'Username' : str, 
    'Timestamp': str,
    'Follower' : int,
    'Friends'  : int,
    'Favorites': int,
    'Retweets' : int,
    'Entities' : str,
    'Sentiment': str,
    'Mentions' : str,
    'Hashtags' : str,
    'URLs'     : str
}

cols = ["Follower","Friends","Favorites",'Retweets']

# %%
data = pd.read_csv("/Users/macbookretina/Desktop/TweetsCOV19.tsv",sep='\t',dtype=col_data, parse_dates=True, names= list(col_data.keys()),error_bad_lines=False, usecols = cols)
data.head()
# Out:
#    Follower  Friends  Favorites  Retweets
# 0       619      770          0         0
# 1     36365    19344         13        17
# 2      5018     1933          0         0
# 3      2219      971          0         0
# 4      9009     4943         26        89

# %%
# define the x & y data.
x = data['Favorites']
y = data['Retweets']

# create the scatter plot.
plt.plot(x, y, 'o', color ='cadetblue', label = 'ret')

# make sure it's formatted.
plt.title("favori Vs. retweet")
plt.xlabel("favorites")
plt.ylabel("retweets")
plt.legend()

plt.show()
# Out:
# /Users/macbookretina/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# define the x & y data.
x = data['Follower']
y = data['Retweets']

# create the scatter plot.
plt.plot(x, y, 'o', color ='cadetblue', label = 'retweet')

# make sure it's formatted.
plt.title("follower Vs. retweet")
plt.xlabel("follower")
plt.ylabel("retweets")
plt.legend()

plt.show()

# %%
# define the x & y data.
x = data['Friends']
y = data['Retweets']

# create the scatter plot.
plt.plot(x, y, 'o', color ='cadetblue', label = 'retweet')

# make sure it's formatted.
plt.title("friends Vs. retweet")
plt.xlabel("friends")
plt.ylabel("retweets")
plt.legend()

plt.show()

# %%
X = data[['Favorites']]
Y = data['Retweets']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
regr = linear_model.LinearRegression()
regr.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 

print_model = model.summary()
print(print_model)
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               Retweets   R-squared (uncentered):                   0.802
# Model:                            OLS   Adj. R-squared (uncentered):              0.802
# Method:                 Least Squares   F-statistic:                          3.264e+07
# Date:                Wed, 12 Aug 2020   Prob (F-statistic):                        0.00
# Time:                        20:32:17   Log-Likelihood:                     -6.8132e+07
# No. Observations:             8077794   AIC:                                  1.363e+08
# Df Residuals:                 8077793   BIC:                                  1.363e+08
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Favorites      3.6227      0.001   5712.754      0.000       3.621       3.624
# ===============================================================================
# Omnibus:                 28207594.870   Durbin-Watson:                    2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   419155098918597.375
# Skew:                          65.745   Prob(JB):                          0.00
# Kurtosis:                   35292.345   Cond. No.                          1.00
# ===============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#To retrieve the intercept:
print(regr.intercept_)
#For retrieving the slope:
print(regr.coef_)
# Out:
# -11.116100087101074
# [3.62712669]

# %%
Y_pred = regr.predict(X_test)
for i in range(len(Y_pred)):
    if Y_pred[i]<0:
        Y_pred[i]=0
Y_pred
# Out:
# array([ 0.        ,  0.        ,  0.        , ..., 32.40942015,
#         0.        , 21.52804009])

# %%
df = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_pred})
df
# Out:
#          Actual    Predicted
# 4385397       1     0.000000
# 5923702       0     0.000000
# 3762119       0     0.000000
# 6065616      24    25.155167
# 5795552     220    97.697701
# 6965367       0     0.000000
# 2310632      22    72.307814
# 3163891       0     0.000000
# 3892181     173   177.494488
# 144781        0     0.000000
# 5173839       0     0.000000
# 492845        0     0.000000
# 3294356       5    50.545054
# 4340899      22     7.019533
# 7503776       0     0.000000
# 5223490       0     0.000000
# 2385864       0     0.000000
# 146949      711   580.105550
# 3877764       0     0.000000
# 3283545       0     0.000000
# 1631814     162   170.240234
# 3108900     698   736.071997
# 6191834       0     0.000000
# 4772947     220   387.867835
# 5020247      10    28.782293
# 8026633       0     0.000000
# 4936391       0     0.000000
# 1031063       1     0.000000
# 6762974       0     0.000000
# 2526327       0     0.000000
# ...         ...          ...
# 6079855       2     0.000000
# 7417001       0     0.000000
# 5714514     172   279.054035
# 6648690      15    28.782293
# 7900606       0     0.000000
# 6936520      29    90.443447
# 96964         0     0.000000
# 2789070      24    17.900913
# 1390748      52    68.680687
# 2341593      21    43.290800
# 1235579       0     0.000000
# 5135994      16    50.545054
# 3480409       0     0.000000
# 6892057       0     0.000000
# 6736591       2     0.000000
# 7141410    5286  2422.685906
# 4387088       6     0.000000
# 4545371       2     0.000000
# 6565882       0     0.000000
# 5853201       0     0.000000
# 3993077       0     0.000000
# 65186         0     0.000000
# 5852074      45   108.579081
# 3875403      14    14.273787
# 6090139       0     0.000000
# 2990262     192    57.799307
# 2910221       0     0.000000
# 3368489      22    32.409420
# 4507470     183     0.000000
# 4853929      29    21.528040
#
# [1615559 rows x 2 columns]

# %%
df.corr()
# Out:
#              Actual  Predicted
# Actual     1.000000   0.891744
# Predicted  0.891744   1.000000

# %%
#plt.scatter(X_test, Y_test,  color='gainsboro')
plt.plot(X_test, Y_test, ls="none", marker='.', ms=12)
plt.plot(X_test, Y_pred, color='red', linewidth=2)
plt.show()
